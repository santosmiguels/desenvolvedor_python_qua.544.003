# %% [markdown]
# # Este é o título de um documento com o notebook e markdown.
#
# Nesta aula iremos aprender sobre como inserir ***markdowns*** dentro de arquivos do tipo **Jupyter Notebook**.
#
# > ***Markdown*** é um tipo de documento muito usado em ciência de dados e também para alimentar inteligência Artificial.
# >
# >Manipular este tipo de arquivo se torna fundamental para dominar as profissões do futuro que dependem da IAs.

# %% [markdown]
# ## Esta é a segunda sessão do documento com markdown
#
# O que diferencia um markdown de um notebook, é que no caso do notebook, ele também é capaz de ler códigos das linguagens de programação *R*, *Julia* e é claro *Python*.

# %% [markdown]
# ## Ckecklist
#
# ### Este é um subtítulo de terceiro nível.
#
# ✅ Python <br>
# ✅ Julia <br>
# ✅ R <br>
#
# ### Linguagens que iremos utilizar no curso:
#
# ✅ Python <br>
# ❌ Julia  <br>
# ❌ R <br>
