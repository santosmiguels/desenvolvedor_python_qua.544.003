# %% [markdown]
# # Aula do dia 04/09/2026
#
# Hoje iremos aprender a trabalha r com células Python. As células Python dentro dos notebook.
# Observe a célula Python abaixo:

# %%
nome = "Alex Machado"
texto = f"Está é uma célula Python escrita pelo melhor programador de todos os tempos: {nome}🙍."
print(texto)
# Out:
# Está é uma célula Python escrita pelo melhor programador de todos os tempos: Alex Machado🙍.

# %% [markdown]
# A célula Python também permite códigos de enrada de dados. Veja:

# %%
nome  = input("Inform seu nome: ").strip().title()
print(nome)

# %% [markdown]
# As células Python são acumulativas, e reconhecem as variáveis das células anteriores.
#
# Observe, por exemplo, a célula abaixo:

# %%
n1 = 5
print(n1)
# Out:
# 5

# %% [markdown]
# O Valor de n1 é claramente 5. Porém, veja na próxima célula e diga qual será o valor da variével resut:

# %%
result = 15 + n1
print(result)
# Out:
# 20

# %% [markdown]
# O valor de result é 20, pois está somando 15 com n1, que tinha o valor de 5.
#
# Mas agora observe a célula abaixo sem executá-la:

# %%
x = 10

# %% [markdown]
# Agora, faça o código abaixo na proxima célula, execute e veja qual é o resultado:

# %%
result = 25 + x
print(result)
# Out:
# 35
